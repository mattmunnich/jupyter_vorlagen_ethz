# %% [markdown]
# # Protocol for experiment 16 "Light Interference"

# %% [markdown]
# **Date:** {2023-MM-DD}
# **Version:** {1 for 1st assignment, 2 for corrected assignment, ...}
#
#  - **Student 1:** {full name}
#  - **Student 2:** {full name}

# %% [markdown]
# ## 1. Introduction
#
# ### 1.1 Introduction to the experiment
#
# - What is the experiment about? What is the objective?
#
# ### 1.2 Summary of theory
#
# - Explanation of the formulas used incl. variable labeling (example from preliminary experiment)
#     - Representation e.g. by
#     "\\$\\$ T = 2\pi \sqrt{\frac{L}{g}} \\$\\$" $\rightarrow$
#     $$T=2\pi\sqrt{\frac{L}{g}}$$
#     where $T$ is the period of oscillation of the pendulum for one oscillation, $L$ is the length of the pendulum, and $g$ is the acceleration due to gravity.
#     - $$\phi = A \exp(-\frac{\gamma t}{2})\cos(\omega t + \alpha)$$
#     where $\phi$ is the displacement of the oscillation, $A$ is the original amplitude of the oscillation, $\gamma$ is the coefficient of friction, and $\omega$ is the angular frequency.
#
# ### 1.3 Tasks
#
# - What are the tasks for the experiment?
#
# ### 1.4 Environmental relevance
#
# - How is the experiment relevant to your studies in environmental science? (1-2 sentences)

# %% [markdown]
# ## 2. Packages and Functions

# %% [markdown]
# ### 2.1 Load packages
# You may not use all of these packages. You can comment out the ones you don't need.

# %%
# import packages  (not every package is used in each notebook template)

# numerical computing
import numpy as np                    # Fundamental package for numerical computing in Python

# uncertainty calculations
from uncertainties import ufloat      # For handling numbers with uncertainties
from uncertainties.umath import *     # For applying mathematical functions with uncertainties
from uncertainties import unumpy      # For handling uncertainties in arrays

# data manipulation and analysis
import pandas as pd                   # Powerful data manipulation and analysis library

# data visualization in tables
from tabulate import tabulate

# data visualization in plots
import matplotlib.pyplot as plt       # Library for creating static, interactive, and animated visualizations

# scientific computing
import scipy as sc                    # Open-source scientific computing library
from scipy.stats import linregress    # For performing linear regression analysis
from scipy.constants import R         # Physical and mathematical constants

# interactive display in Jupyter Notebook
from IPython.display import display, Markdown, Image   # For displaying rich content (e.g., Markdown) in Jupyter Notebook

# standard mathematical functions
import math                          # Python's built-in math functions

# widgets (to create elements such as dynamic input/output boxes)
import ipywidgets as widgets

# %% [markdown]
# ### 2.2 Define functions

# %%
# example: 

def my_function(param1_placeholder, param2_placeholder):
    
    value = 'Replace with your calculation'
    return value

# %% [markdown]
# #### <span style='color:darkcyan'> Your functions: </span>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Tip</b>: <br/>
#     1) Here is the place to <b>define all the functions you need</b> in this notebook. This helps to keep your notebook clear and structured.<br/>
#     2) Add <b>comments</b> to your functions (e.g. what is the function good for, what happens in each line, etc.), so that you and your lab partner will still be able to understand the code at a later time.

# %% [markdown]
# ## 3. Experiments

# %% [markdown]
# ### 3.1 Experiment 1: Fresnel biprism
# <span style='color:indigo'> <i>Determine the wavelength $\lambda$ of the diode laser used in the experiment using the Fresnel
# biprism.</i></span>

# %% [markdown]
# __a) Measurement of the distance d between the maxima of the interference image behind the biprism:__

# %%
display(Image(filename="./16_graphics/1.png"))

# %%
display(Image(filename="./16_graphics/2.png"))

# %% [markdown]
# #### 3.1.1 a) Measurement data

# %%
# Example:
# Variable = ufloat(measured value, absolute error) # [unit]
f_test = ufloat(19.4,0.1) # [mm]

b_1a = ...        # [unit]  image distance
f_1a = 11         # [mm]    focal length of the lens
d_prime_1a = ...  # [unit]  distance between subsequent maxima and minima

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Tip</b>: Take care when choosing names for your variables - make sure that you <b>don't use the same name for different variables</b> (throughout the whole notebook!) <br/>
#     If you measure the same quantity in more than one experiment, you can e.g. include the experiment number in the variable name to make it unique. <br/>
#     <small>Otherwise the value of the variable will depend on the order in which you execute the cells, which may cause confusion and wrong results if you don't always execute them from top to bottom.</small><br/>

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %%
# for example

print("Image distance: b =", ...,"mm")
print("Focal length of the lens: f =",...,"mm")
print("Distance between subsequent maxima and minima on the screen: d' = ",...,"mm")
# Out:
# Image distance: b = Ellipsis mm
# Focal length of the lens: f = Ellipsis mm
# Distance between subsequent maxima and minima on the screen: d' =  Ellipsis mm

# %% [markdown]
# #### 3.1.2 a) Evaluation

# %%
# object distance 
a_1a = ...   # [unit]

# real distance
d_1a = ...   # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# __b) Measurement of the angle $\beta$ between the interfering parallel beams and calculation of $\lambda$:__

# %%
display(Image(filename="./16_graphics/3.png"))

# %% [markdown]
# #### 3.1.1 b) Measurement data

# %%
L_1b = ...        # [unit]  
B_1b = ...        # [unit]    
l_prime_1b = ...  # [unit]  
f1_1b = ...       # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.1.2 b) Evaluation

# %%
A_1b = ...        # [unit]  
l_1b = ...        # [unit]    
beta_1b = ...     # [unit]  
lambda_1b = ...   # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# ### 3.2 Experiment 2: Diffraction at the wire or slit (principle of Babinet)
# <span style="color: indigo;"><i>
#         a) Determine experimentally and computationally the distance $d$ between two neighbouring intensity maxima for the diffraction at a wire of known thickness $b$ and the previously found wavelength of the laser.<br/>
#         b) Replace the wire by a slit and change its width until the distance between two neighbouring maxima is the same as previously measured.<br/>
#     c) Measure the width of the slit. Do so by an optical imaging of the slit at a screen.</i>
# </span>

# %% [markdown]
# __a) Diffraction at the wire (top view):__

# %%
display(Image(filename="./16_graphics/4.png"))

# %% [markdown]
# #### 3.2.1 a) Measurement data

# %%
b_2a = ...        # [unit]  wire thickness
S_2a = ...        # [unit]  
d_measured_2a = ...  # [unit]  measured distance of the maxima

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.2.2 a) Evaluation

# %%
# calculated distance between the maxima (calculated from lambda, b and S)
d_calc_2a = ...   # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# __b) Diffraction at the slit (top view):__

# %%
display(Image(filename="./16_graphics/5.png"))

# %% [markdown]
# <span style='color:darkcyan'> <i>Adjust the gap width at the same distance $S$ to the screen so that the
# distance $d$ between the maxima is the same as for the wire.</i></span>

# %% [markdown]
# #### 3.b.1 b) Measurement data

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.2.2 b) Evaluation

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# __c) Determination of the gap width (top view):__

# %% [markdown]
# <span style='color:darkcyan'> <i>Now image the slit with the lenses $L_2$ and $L_1$ (enlarged) on the screen
# and calculate the slit width from the width of this image.</i></span>

# %%
display(Image(filename="./16_graphics/6.png"))

# %% [markdown]
# #### 3.2.1 c) Measurement data

# %%
C_2c = ...   # [unit]
L_2c = ...   # [unit]
B_2c = ...   # [unit]
f1_2c = ...  # [unit]
A_2c = ...   # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.2.2 c) Evaluation

# %%
b_prime_2c = ...   # [unit]
b_bar_2c = ...     # [unit]
diff_2c = ...      # [unit] L-A
b_2c = ...         # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# ### 3.3 Experiment 3: Diffraction effects at Lykopodium platelets
# <span style="color: indigo;"><i>
#         Lykopodium is a material that is composed of
# roughly equally-sized circular platelets. Determine the diameter of these Lykopodium particles from the diffraction pattern that they generate. For this, disperse the platelets on a glass
# substrate to see its diffraction pattern and also compare your result with the size measured
# with an optical microscope.</i>
# </span>

# %%
display(Image(filename="./16_graphics/7.png"))

# %% [markdown]
# #### 3.3.1 Measurement data

# %%
L_3 = ...           # [unit]  
rho1_3 = ...        # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.2.2 Evaluation

# %%
D_Lyco_3 = ...      # [unit] Diameter of Lycopodium particles, calculated with rho1
D_micro_3 = ...     # [unit] microscope

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# <span style='color:darkcyan'> <i>Compare your results to the values for $\rho$ obtained from
# the diffraction method.</i></span>

# %% [markdown]
# ### 3.4 Experiment 4: Measurement of the pinhole sizeand the hair width from diffraction pattern
# <span style="color: indigo;"><i>
#          In addition, determine the following dimensions using the methods already discussed above:<br/>
# a) diameter of a pinhole<br>
# b) thickness of your own hair</i>
# </span>

# %% [markdown]
# __a) Durchmesser der Lochblende:__

# %%
display(Image(filename="./16_graphics/8.png"))

# %% [markdown]
# #### 3.4.1 a) Measurement data

# %%
L_4a = ...           # [unit]  
rho1_4a = ...        # [unit]  
rho2_4a = ...        # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.4.2 a) Evaluation

# %%
D1_4a = ...     # [unit] 
D2_4a = ...     # [unit]

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# __b) Dicke eines Haares:__

# %% [markdown]
# <span style='color:darkcyan'> <i>Analog zu Aufgabe 2. Diesmal wird der Abstand $d$ der Maxima gemessen
# und die Haardicke $b$ mit den Grössenl, $L$ und $d$ berechnet.</i></span>

# %% [markdown]
# #### 3.4.1 b) Measurement data

# %%
L_4b = ...        # [unit]  
d_4c = ...        # [unit]  distance between the maxima

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your data (incl. errors and units).</i></span>

# %% [markdown]
# #### 3.4.2 a) Evaluation

# %%
b_4b = ...     # [unit] thickness of the hair

# %% [markdown]
# <span style='color:darkcyan'> <i>Print your results
#     (incl. errors and units).</i></span>

# %% [markdown]
# ## 4 Discussion

# %% [markdown]
# <span style='color:darkcyan'> <i>Are your results realistic? Why (not)? Comparison with theory? </i></span>

# %% [markdown]
# <span style='color:darkcyan'> <i>What measurement errors were assumed? Why? <br/>
#     What are the main reasons for the errors in your results and how do they come about?</i></span>

# %% [markdown]
# <span style='color:darkcyan'> <i>How would you try to reduce the error further? Could you improve the accuracy of the experiment? </i></span>

# %% [markdown]
# <span style='color:darkcyan'> <i>If you were to repeat the experiment, what would you do differently and why?</i></span>
